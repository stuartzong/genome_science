# %%
import pandas as pd
import numpy as np
import string as s
import seaborn as sns
import math
# import tables
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style, colors
from itertools import groupby
import matplotlib.patches as patches
from matplotlib import gridspec
import scipy.stats as stats
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, fclusterdata, leaves_list
from scipy.spatial.distance import pdist
from scipy.ndimage.interpolation import shift
# matplotlib.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 6)
# matplotlib.rcParams['figure.facecolor'] = 'white'
import mpl_toolkits.mplot3d.axes3d as p3
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets.samples_generator import make_swiss_roll
matplotlib.style.use('ggplot')
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # constants

# %%
wkdir = '/projects/da_workspace/software/ChromHMM/Cervical_all_patients'
mark = ["H3K27ac","H3K27me3","H3K36me3","H3K4me1","H3K4me3","H3K9me3"]

# %% [markdown]
# # running ChromHMM

# %% [markdown]
# # prep input files: cellmarkerfiletable.txt, symlink peak files in  peak_bed_files directory

# %%
# %%bash -s $wkdir $mark
#
# wkdir=$1
# # mark=$2
# echo $wkdir, $mark
# cd $wkdir
# for mark in H3K27ac H3K27me3 H3K36me3 H3K4me1 H3K4me3 H3K9me3
# do
#     ls -1 /projects/chipseq/macs/A*/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/*/*$mark*Peak|grep -v gappedPeak > a.tmp
#     cat a.tmp |awk -F "/" '{print $5"\t"$0}'|awk -F "_" '{print $3"\t"$0}'>d.tmp
#
#     while read a b c;do grep $b 57_chipseq_samples_library_ids.csv|cut -f 1|\
#     awk -v lib=$b -v path=$c -v mark=$a -F "-01" '{print $1"\t"lib"\t"mark"\t"path}' ;done \
#     < d.tmp |sort -k1 -k2 > $mark"_peak_file_path.txt"
#
#     rm a.tmp  d.tmp
#     head -2 $mark"_peak_file_path.txt"
#     wc -l $mark"_peak_file_path.txt";
# done
# Out:
# /projects/da_workspace/software/ChromHMM/Cervical_all_patients,
# HTMCP-03-06-02001	A84615	H3K27ac	/projects/chipseq/macs/A84615/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/370/A84615_H3K27ac_peaks.narrowPeak
# HTMCP-03-06-02002	A94516	H3K27ac	/projects/chipseq/macs/A94516/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/691/A94516_H3K27ac_peaks.narrowPeak
# 54 H3K27ac_peak_file_path.txt
# HTMCP-03-06-02001	A84613	H3K27me3	/projects/chipseq/macs/A84613/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/374/A84613_H3K27me3_peaks.broadPeak
# HTMCP-03-06-02002	A94514	H3K27me3	/projects/chipseq/macs/A94514/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/689/A94514_H3K27me3_peaks.broadPeak
# 54 H3K27me3_peak_file_path.txt
# HTMCP-03-06-02001	A84614	H3K36me3	/projects/chipseq/macs/A84614/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/371/A84614_H3K36me3_peaks.broadPeak
# HTMCP-03-06-02002	A94515	H3K36me3	/projects/chipseq/macs/A94515/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/690/A94515_H3K36me3_peaks.broadPeak
# 54 H3K36me3_peak_file_path.txt
# HTMCP-03-06-02001	A84610	H3K4me1	/projects/chipseq/macs/A84610/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/372/A84610_H3K4me1_peaks.broadPeak
# HTMCP-03-06-02002	A94511	H3K4me1	/projects/chipseq/macs/A94511/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/686/A94511_H3K4me1_peaks.broadPeak
# 53 H3K4me1_peak_file_path.txt
# HTMCP-03-06-02001	A84611	H3K4me3	/projects/chipseq/macs/A84611/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/369/A84611_H3K4me3_peaks.narrowPeak
# HTMCP-03-06-02002	A94512	H3K4me3	/projects/chipseq/macs/A94512/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/687/A94512_H3K4me3_peaks.narrowPeak
# 53 H3K4me3_peak_file_path.txt
# HTMCP-03-06-02001	A84612	H3K9me3	/projects/chipseq/macs/A84612/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/373/A84612_H3K9me3_peaks.broadPeak
# HTMCP-03-06-02002	A94513	H3K9me3	/projects/chipseq/macs/A94513/75nt/hg19a/bwa-mem-0.7.6a-sb/MACS_2.1.1.20160309/688/A94513_H3K9me3_peaks.broadPeak
# 49 H3K9me3_peak_file_path.txt

# %%
# format and concatenate the peak files from each mark

# %%
# %%bash
# ssh gphost06
# # step 1: make chromhmm input file cellmarkerfiletable.txt, this file needs to be 3 columns, patient, mark, and mark peak file.
# # step 2: create symlink to the MCS2 broadPeaks and narrowPeaks files
# cd /projects/da_workspace/software/ChromHMM/Cervical_all_patients
# cat *.marks|awk -F "/" '{print $0"\t"$11}' > cellmarkfiletable.txt.full.path
# while read a b c d;do grep $a cellmarkfiletable.txt.full.path;done < H3K9me3_peak_file_path.txt.with.6.marks>cellmarkfiletable.txt.full.path.6.marks
# mkdir /projects/da_workspace/software/ChromHMM/Cervical_all_patients/peak_bed_files
# cd /projects/da_workspace/software/ChromHMM/Cervical_all_patients/peak_bed_files
# while read a b c d e;do ln -s $d $e;done < /projects/da_workspace/software/ChromHMM/Cervical_all_patients/cellmarkfiletable.txt.full.path.6.marks
#
# # run chromHMM BinarizeBed, memory may need to significantly larger, e.g. -Xmx120G
# cd /projects/da_workspace/software/ChromHMM
# /gsc/software/linux-x86_64-centos6/jdk1.8.0_102/bin/java -mx1600M -jar ChromHMM.jar BinarizeBed -b 200 -peaks CHROMSIZES/hg19.txt /projects/da_workspace/software/ChromHMM/Cervical_all_patients/peak_bed_files/ /projects/da_workspace/software/ChromHMM/Cervical_all_patients/cellmarkfiletable.txt /projects/da_workspace/software/ChromHMM/Cervical_all_patients/binary/
#
# # add chr suffix to binary files
# cd /projects/da_workspace/software/ChromHMM/Cervical_all_patients/binary/
# for f in *_binary.txt;do awk '/^HTMCP/{$2="chr"$2} 1' $f |sed 's/ /\t/g'> $f.chr_suffix;done
# rm *_binary.txt
#
# # run chromHMM, need to run on gphost because of memory requirement
# # /gsc/software/linux-x86_64-centos6/jdk1.8.0_102/bin/java -Xmx50g -jar ChromHMM.jar LearnModel -b 200 -p 0 ./Cervical_all_patients/binary/ ./Cervical_all_patients/18_states 18 hg19
#
# # or run for multiple states models
# cd /projects/da_workspace/software/ChromHMM
# for f in 15 16 17 18 19 20 21;do mkdir ./Cervical_all_patients/$f"_states"; /gsc/software/linux-x86_64-centos6/jdk1.8.0_102/bin/java -Xmx50g -jar ChromHMM.jar LearnModel -b 200 -p 0 ./Cervical_all_patients/binary/ ./Cervical_all_patients/$f"_states" $f hg19;done
# for f in 22 23 24;do /gsc/software/linux-x86_64-centos6/jdk1.8.0_102/bin/java -Xmx100g -jar ChromHMM.jar LearnModel -b 200 -p 0 ./Cervical_all_patients/binary/ ./Cervical_all_patients/$f"_states" $f hg19;done
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# mkdir: cannot create directory `/projects/da_workspace/software/ChromHMM/Cervical_all_patients/peak_bed_files': File exists
# ln: target `A84615_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84613_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84614_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84610_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84611_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84612_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84615_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84613_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84614_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84610_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84611_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84612_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94516_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94514_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94515_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94511_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94512_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94513_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94516_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94514_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94515_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94511_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94512_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94513_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84622_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84620_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84621_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84617_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84618_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84619_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84622_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84620_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84621_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84617_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84618_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84619_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84636_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84634_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84635_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84631_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84632_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84633_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84636_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84634_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84635_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84631_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84632_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84633_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84643_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84641_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84642_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84638_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84639_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84640_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84643_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84641_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84642_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84638_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84639_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84640_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91505_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91503_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91504_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91500_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91501_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91502_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91505_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91503_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91504_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91500_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91501_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91502_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91512_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91510_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91511_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91507_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91508_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91509_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91512_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91510_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91511_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91507_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91508_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91509_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84657_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84655_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84656_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84652_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84653_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84654_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84657_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84655_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84656_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84652_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84653_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84654_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84664_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84662_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84663_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84659_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84660_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84661_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84664_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84662_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84663_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84659_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84660_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84661_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91519_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91517_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91518_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91514_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91515_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91516_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91519_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91517_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91518_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91514_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91515_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91516_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91526_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91524_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91525_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91521_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91522_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91523_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91526_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91524_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91525_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91521_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91522_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91523_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84671_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84669_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84670_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84666_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84667_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84668_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84671_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84669_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84670_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84666_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84667_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84668_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84678_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84676_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84677_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84673_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84674_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84675_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84678_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84676_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84677_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84673_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84674_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84675_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84692_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84690_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84691_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84687_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84688_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84689_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84692_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84690_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84691_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84687_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84688_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84689_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84699_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84697_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84698_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84694_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84695_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84696_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84699_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84697_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84698_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84694_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84695_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84696_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84706_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84704_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84705_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84701_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84702_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84703_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84706_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84704_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84705_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84701_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84702_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84703_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84713_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84711_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84712_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84708_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84709_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84710_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84713_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84711_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84712_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84708_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84709_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84710_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84720_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84718_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84719_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84715_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84716_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84717_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84720_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84718_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84719_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84715_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84716_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84717_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91533_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91531_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91532_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91528_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91529_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91530_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91533_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91531_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91532_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91528_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91529_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91530_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84727_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84725_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84726_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84722_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84723_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84724_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84727_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84725_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84726_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84722_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84723_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84724_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84685_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84683_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84684_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84680_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84681_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84682_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84685_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84683_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84684_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84680_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84681_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84682_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A92257_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A92255_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A92256_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A92252_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A92253_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A92254_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A92257_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A92255_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A92256_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A92252_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A92253_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A92254_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84734_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84732_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84733_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84729_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84730_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84731_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84734_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84732_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84733_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84729_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84730_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84731_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84741_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84739_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84740_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84736_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84737_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84738_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84741_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84739_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84740_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84736_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84737_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84738_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91554_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91552_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91553_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91549_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91550_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91551_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91554_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91552_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91553_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91549_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91550_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91551_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91561_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91559_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91560_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91556_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91557_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91558_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91561_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91559_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91560_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91556_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91557_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91558_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84748_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84746_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84747_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84743_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84744_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84745_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84748_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84746_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84747_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84743_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84744_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84745_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84755_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84753_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84754_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84750_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84751_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84752_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84755_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84753_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84754_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84750_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84751_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84752_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84811_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84809_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84810_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84806_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84807_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84808_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84811_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84809_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84810_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84806_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84807_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84808_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84762_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84760_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84761_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84757_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84758_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84759_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84762_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84760_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84761_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84757_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84758_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84759_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94368_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94366_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94367_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94363_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94364_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94365_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94368_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94366_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94367_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94363_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94364_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94365_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84769_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84767_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84768_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84764_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84765_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84766_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84769_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84767_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84768_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84764_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84765_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84766_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84804_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84802_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84803_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84799_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84800_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84801_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84804_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84802_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84803_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84799_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84800_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84801_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84776_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84774_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84775_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84771_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84772_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84773_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84776_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84774_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84775_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84771_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84772_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84773_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84783_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84781_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84782_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84778_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84779_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84780_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84783_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84781_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84782_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84778_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84779_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84780_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84790_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84788_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84789_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84785_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84786_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84787_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84790_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84788_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84789_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84785_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84786_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84787_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84797_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84795_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84796_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84792_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84793_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84794_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84797_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84795_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84796_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84792_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84793_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84794_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91596_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91594_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91595_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91591_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91592_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91593_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91596_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91594_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91595_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91591_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91592_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91593_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91603_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91601_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91602_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91598_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91599_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91600_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A91603_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A91601_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A91602_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A91598_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A91599_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A91600_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84825_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84823_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84824_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84820_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84821_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84822_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84825_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84823_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84824_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84820_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84821_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84822_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94523_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94521_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94522_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94518_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94519_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94520_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94523_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94521_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94522_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94518_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94519_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94520_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84832_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84830_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84831_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84827_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84828_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84829_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84832_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84830_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84831_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84827_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84828_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84829_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94530_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94528_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94529_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94525_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94526_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94527_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A94530_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A94528_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A94529_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A94525_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A94526_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A94527_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84839_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84837_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84838_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84834_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84835_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84836_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84839_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84837_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84838_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84834_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84835_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84836_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84846_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84844_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84845_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84841_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84842_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84843_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84846_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84844_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84845_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84841_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84842_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84843_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84853_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84851_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84852_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84848_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84849_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84850_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84853_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84851_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84852_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84848_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84849_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84850_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84860_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84858_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84859_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84855_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84856_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84857_H3K9me3_peaks.broadPeak' is not a directory
# ln: target `A84860_H3K27ac_peaks.narrowPeak' is not a directory
# ln: target `A84858_H3K27me3_peaks.broadPeak' is not a directory
# ln: target `A84859_H3K36me3_peaks.broadPeak' is not a directory
# ln: target `A84855_H3K4me1_peaks.broadPeak' is not a directory
# ln: target `A84856_H3K4me3_peaks.narrowPeak' is not a directory
# ln: target `A84857_H3K9me3_peaks.broadPeak' is not a directory
