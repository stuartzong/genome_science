# %%
import matplotlib
import csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style, colors
from matplotlib import gridspec

matplotlib.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8, 6)

# %%
f1 = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/124_patients_bam_vcf_20190115.txt'
df = pd.read_csv(f1, sep='\t', index_col='patient')
df.head(2)

df.columns

ndf = pd.DataFrame(df['mutseq_snv_vcf'].dropna()).reset_index()

ndf.head(2)

# ndf = ndf.reindex(patient)
# ndf.shape
# ndf.loc['HTMCP-03-06-02261',]
# Out:
#              patient                                     mutseq_snv_vcf
# 0  HTMCP-03-06-02001  /projects/somatic/NCI_SAIC_HIV_Cervical/HTMCP-...
# 1  HTMCP-03-06-02002  /projects/somatic/NCI_SAIC_HIV_Cervical/HTMCP-...

# %%
f = '/projects/trans_scratch/validations/workspace/szong/Cervical/mutsig2cv/118_patients.txt'
df = pd.read_csv(f,header=None)
df.columns = ['patient']
df.head()
# Out:
#              patient
# 0  HTMCP-03-06-02001
# 1  HTMCP-03-06-02002
# 2  HTMCP-03-06-02003
# 3  HTMCP-03-06-02006
# 4  HTMCP-03-06-02008

# %% [markdown]
# # run below templated script locally or on gphost06, source below path first
# #source /gsc/software/linux-x86_64-centos6/vcf2maf-1.6.6/profile.sh

# %%
from jinja2 import Environment, FileSystemLoader
import logging
import colorlog

logger = colorlog.getLogger()
logger.setLevel(logging.DEBUG)
handler = logging.StreamHandler()
handler.setLevel(logging.DEBUG)
handler.setFormatter(
    colorlog.ColoredFormatter('%(log_color)s%(levelname)s:%(name)s:%(message)s'))
logger.addHandler(handler)

# %%
template_dir = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/'
template_file_name = 'vcf2maf_template.txt'

# %%
def populate_template(patient, input_vcf, output_maf, 
                      template_dir, template_file_name, templated_file_name):
    jinja2_env = Environment(loader=FileSystemLoader([template_dir]),
                             trim_blocks=True)
    template = jinja2_env.get_template(template_file_name)
    with open(templated_file_name, 'w') as opf:
        content = template.render(patient = patient,
                                  input_vcf = input_vcf,
                                  output_maf = output_maf)
        opf.write(content)
        logger.info('templated {0}'.format(templated_file_name))
    return template_file_name

# %%
filtered_vcf_path = '/projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/'

# %%
for vcf_type in ['snv']:
    
    for ix,row in ndf.iterrows():
        patient = row.patient
        input_vcf = row.mutseq_snv_vcf
#         input_vcf = '{0}vcfs/{1}.{2}.vcf'.format(filtered_vcf_path, patient, vcf_type)
        output_maf = '{0}mafs/{1}.{2}.maf'.format(filtered_vcf_path, patient, vcf_type)
        templated_file_name = '{0}{1}.{2}.sh'.format(filtered_vcf_path, patient, vcf_type)
#         print(patient, input_vcf, output_maf, templated_file_name)
        populate_template(patient, input_vcf, output_maf, 
                          template_dir, template_file_name, 
                          templated_file_name)
# Out:
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02001.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02001.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02002.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02002.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02003.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02003.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02006.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02006.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02007.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02007.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02008.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02008.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02012.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02012.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02013.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02013.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02020.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02020.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02026.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02026.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02036.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02036.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02037.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02037.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02040.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02040.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02042.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02042.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02046.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02046.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02047.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02047.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02054.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02054.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02057.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02057.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02058.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02058.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02109.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02109.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02061.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02061.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02063.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02063.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02068.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02068.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02070.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02070.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02071.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02071.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02074.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02074.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02075.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02075.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02076.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02076.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02085.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02085.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02089.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02089.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02092.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02092.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02097.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02097.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02098.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02098.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02099.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02099.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02103.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02103.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02108.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02108.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02139.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02139.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02110.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02110.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02113.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02113.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02120.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02120.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02125.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02125.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02128.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02128.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02144.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02144.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02145.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02145.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02147.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02147.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02149.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02149.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02150.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02150.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02155.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02155.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02156.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02156.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02174.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02174.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02175.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02175.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02176.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02176.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02180.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02180.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02185.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02185.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02194.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02194.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02196.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02196.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02203.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02203.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02209.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02209.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02210.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02210.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02214.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02214.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02215.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02215.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02148.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02148.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02151.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02151.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02152.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02152.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02170.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02170.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02179.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02179.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02205.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02205.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02213.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02213.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02216.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02216.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02157.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02157.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02195.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02195.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02202.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02202.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02204.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02204.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02217.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02217.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02219.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02219.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02225.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02225.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02230.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02230.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02235.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02235.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02238.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02238.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02239.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02239.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02240.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02240.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02242.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02242.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02182.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02182.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02197.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02197.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02222.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02222.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02256.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02256.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02259.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02259.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02260.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02260.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02261.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02261.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02262.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02262.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02264.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02264.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02266.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02266.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02267.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02267.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02268.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02268.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02320.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02320.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02322.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02322.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02326.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02326.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02328.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02328.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02330.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02330.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02332.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02332.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02333.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02333.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02335.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02335.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02340.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02340.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02341.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02341.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02344.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02344.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02346.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02346.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02354.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02354.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02377.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02377.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02392.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02392.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02393.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02393.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02396.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02396.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02411.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02411.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02414.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02414.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02417.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02417.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02424.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02424.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02427.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02427.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02428.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02428.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02434.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02434.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02435.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02435.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02437.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02437.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02441.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02441.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02442.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02442.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02447.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02447.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02448.snv.sh
# INFO:root:templated /projects/trans_scratch/validations/workspace/szong/Cervical/variant_bwamem/124_patients_new/mutationseq_vcfs/HTMCP-03-06-02448.snv.sh

# %%
f = '/projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/mafs/combined.snvs.indels_123_patients_coding.txt'
df = pd.read_csv(f, sep='\t')
df.head(2)
# Out:
# /projects/da_workspace/software/miniconda/envs/dlpy3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (4,40,43,68,70,71,72,74,83,84,85,86,87,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0         NaN               0      .     GRCh37          1          833556
# 1  AL589739.1               0      .     GRCh37          1         2258860
#
#    End_Position Strand Variant_Classification Variant_Type   ...   ExAC_AF  \
# 0        833556      +                    IGR          SNP   ...       NaN
# 1       2258860      +      Missense_Mutation          SNP   ...       NaN
#
#   ExAC_AF_AFR ExAC_AF_AMR ExAC_AF_EAS  ExAC_AF_FIN ExAC_AF_NFE ExAC_AF_OTH  \
# 0         NaN         NaN         NaN          NaN         NaN         NaN
# 1         NaN         NaN         NaN          NaN         NaN         NaN
#
#   ExAC_AF_SAS GENE_PHENO  FILTER
# 0         NaN        NaN    PASS
# 1         NaN        NaN    PASS
#
# [2 rows x 109 columns]

# %%
dfn = df[df.Variant_Classification!='IGR']

# %%
of = '/projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/mafs/combined.snvs.indels_123_patients_coding_removed_IGR.txt'
dfn.to_csv(of, sep='\t', index=False)

# %% [markdown]
# # below works too. but outdated

# %%
from string import Template
s = Template('$who likes $what')
s.substitute(who='tim', what='kung pao')


s1 = Template('mkdir /projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/mafs/$patient')
s2 = Template('cd /projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/mafs/$patient') 
s3 = Template('/gsc/software/linux-x86_64-centos6/perl-5.22.0/bin/perl /gsc/software/linux-x86_64-centos6/vcf2maf-1.6.6/vcf2maf.pl --input-vcf  $vcf --output-maf $patient.snv.maf --tumor-id  $patient')
s4 = Template('_N --vep-path /gsc/software/linux-x86_64-centos6/vcf2maf-1.6.6/vep --vep-data /projects/analysis/vepdata --vcf-tumor-id TUMOR --vcf-normal-id NORMAL --custom-enst /gsc/software/linux-x86_64-centos6/vcf2maf-1.6.6/data/isoform_overrides_uniprot --output-directory /projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/mafs/$patient')

for ix,row in df.iterrows():
    patient=row.patient
    vcf = row.snv
    f = '/projects/trans_scratch/validations/workspace/szong/Cervical/mutsigcv/123_patients/{}.snv.sh'.format(patient)
    with open(f, 'a') as fh:
#     fh.write('aaa\n')
        fh.write(s1.substitute(patient=patient, vcf=vcf))
        fh.write('\n')
        fh.write(s2.substitute(patient=patient, vcf=vcf))
        fh.write('\n')        
        fh.write(s3.substitute(patient=patient, vcf=vcf))
        fh.write('_T --normal-id ')
        fh.write(patient)
        fh.write(s4.substitute(patient=patient, vcf=vcf))
        fh.write('\n')
    fh.close()
# Out:
# 'tim likes kung pao'
