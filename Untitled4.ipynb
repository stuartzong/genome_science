# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = '/home/szong/Downloads/HTMCP_Cervical_Master_Patient_Table_V6_20190813.xlsx'
df = pd.read_excel(f)
df.head(2)
# Out:
#              Patient     Cohort HIV status HAART therapy prior to dx  \
# 0  HTMCP-03-06-02001  Discovery   Positive                       YES
# 1  HTMCP-03-06-02002  Discovery   Negative                       NaN
#
#        Stage Grade               Histology from clinical data Final histology  \
# 0  Stage IIB    G2  Squamous Cell Carcinoma; Non-Keratinizing        Squamous
# 1  Stage IB1    G3  Squamous Cell Carcinoma; Non-Keratinizing        Squamous
#
#   Pathology comment   Age  ...  Signature13_APOBEC (nnls) Max APOBEC score  \
# 0               NaN  56.0  ...                      0.236            0.316
# 1               NaN  62.0  ...                      0.133            0.260
#
#   CD8 T-cells CD4 T-cells  T-cell content  Cibersort p-value  \
# 0       0.043       0.229           0.272                0.0
# 1       0.217       0.322           0.648                0.2
#
#    DNA methylation clusters  RNA-Seq clusters  HRD score  Tumour content
# ...

# %%
df['HIV status'].head()
df[['HIV status', 'Age']].head()
# Out:
#   HIV status   Age
# 0   Positive  56.0
# 1   Negative  62.0
# 2   Positive  39.0
# 3   Negative  34.0
# 4   Negative  61.0

# %%
import matplotlib.pyplot as plt
df['Age'].hist()
plt.show()

# %%
df.query('Age >60 & Age<63')
# Out:
#                Patient     Cohort HIV status HAART therapy prior to dx  \
# 1    HTMCP-03-06-02002  Discovery   Negative                       NaN
# 4    HTMCP-03-06-02008  Discovery   Negative                       NaN
# 17   HTMCP-03-06-02063  Discovery   Negative                       NaN
# 121  HTMCP-03-06-02157   Excluded   Negative                       NaN
#
#           Stage Grade               Histology from clinical data  \
# 1     Stage IB1    G3  Squamous Cell Carcinoma; Non-Keratinizing
# 4    Stage IIIB    G2  Squamous Cell Carcinoma; Non-Keratinizing
# 17    Stage IIB    G2  Squamous Cell Carcinoma; Non-Keratinizing
# 121  Stage IIIA    G3  Squamous Cell Carcinoma; Non-Keratinizing
#
#     Final histology                     Pathology comment   Age  ...  \
# 1          Squamous                                   NaN  62.0  ...
# 4          Squamous                                   NaN  61.0  ...
# 17         Squamous                                   NaN  62.0  ...
# ...
